# %%
import pandas as pd

# %% [markdown]
# ## Reading files

# %%
wh2018 = pd.read_csv('2018_v2.csv')
wh2019 = pd.read_csv('2019_v2.csv')

# %% [markdown]
# Adding extra column to identify year of population

# %%
wh2018['year'] = 2018
wh2019['year'] = 2019

# %% [markdown]
# Union of three files

# %%
wh = pd.concat([wh2018,wh2019])

# %%
wh.columns
# Out:
# Index(['Unnamed: 0', 'Overall rank', 'Country or region', 'Score',
#        'GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'year'],
#       dtype='object')

# %% [markdown]
# ## Ejercicios
#
# 1. Partiendo de Wh, realice un analisis de valores nulos. que porcentaje de valores nulos se encuentran en cada columna por anio. presente el analisis en un dataframe

# %% [markdown]
# Ejemplo:

# %%
pd.DataFrame({
    "year": [2017,2017]
    , "column" : ["Happiness.Rank","Whisker.low"]
    , "percentage.of.nans" : [0.2,0.2]
})
# Out:
#    year          column  percentage.of.nans
# 0  2017  Happiness.Rank                 0.2
# 1  2017     Whisker.low                 0.2

# %% [markdown]
# # Resolución ejercicio uno

# %%
wh['year'].isna().mean()
# Out:
# 0.0

# %% [markdown]
# 2. partiendo de Wh, por año muestre un resumen de todas las columnas.
#
# nota: aunque solo tenemos tres años, que pasaria si en nuestro dataframe tenemos 20 años? resuelva su ejercicio lo mas dinamico que se pueda
#
# # Resolución ejercicio dos

# %%
tranform_to_string = ['year']
for c_ in tranform_to_string: wh[c_] = wh[c_].astype(str)
wh.dtypes
# Out:
# Unnamed: 0                      float64
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# year                             object
# dtype: object

# %%
wh.describe()
# Out:
#        Unnamed: 0  Overall rank       Score  GDP per capita  Social support  \
# count  156.000000    312.000000  301.000000      294.000000      292.000000
# mean    77.500000     78.500000    5.382292        0.903663        1.206839
# std     45.177428     45.104737    1.110277        0.397013        0.302336
# min      0.000000      1.000000    2.853000        0.000000        0.000000
# 25%     38.750000     39.750000    4.516000        0.606500        1.047750
# 50%     77.500000     78.500000    5.386000        0.960000        1.265000
# 75%    116.250000    117.250000    6.174000        1.227500        1.455500
# max    155.000000    156.000000    7.769000        2.096000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               296.000000                    290.000000  285.000000
# mean                  0.663105                      0.421452    0.182751
# std                   0.254413                      0.157640    0.097309
# min                   0.000000                      0.000000    0.000000
# 25%                   0.488250                      0.314000    0.110000
# 50%                   0.699000                      0.444000    0.175000
# 75%                   0.861000                      0.543000    0.244000
# max                   1.141000                      0.724000    0.598000
#
#        Perceptions of corruption
# count                 298.000000
# mean                    0.111500
# std                     0.094909
# min                     0.000000
# 25%                     0.050000
# 50%                     0.082000
# 75%                     0.141750
# max                     0.457000

# %% [markdown]
# 3. partiendo de Wh, remplace los valores NaN de las columnas por su mean, el mean debe de ser calculado por año para ser mas exacto
#
# # Resolución ejercicio tres

# %%
wh.fillna(wh2018.mean())
# Out:
# C:\Users\artic\AppData\Local\Temp/ipykernel_182884/2231093063.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wh.fillna(wh2018.mean())
#      Unnamed: 0  Overall rank         Country or region  Score  \
# 0           0.0             1                   Finland  7.632
# 1           1.0             2                    Norway  7.594
# 2           2.0             3                   Denmark  7.555
# 3           3.0             4                   Iceland  7.495
# 4           4.0             5               Switzerland  7.487
# ..          ...           ...                       ...    ...
# 151        77.5           152                    Rwanda  3.334
# 152        77.5           153                  Tanzania  3.231
# 153        77.5           154               Afghanistan  3.203
# 154        77.5           155  Central African Republic  3.083
# 155        77.5           156               South Sudan  2.853
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.305        1.592000                    0.874
# 1             1.456        1.582000                    0.861
# 2             1.351        1.590000                    0.868
# 3             1.343        1.205915                    0.914
# 4             1.420        1.549000                    0.927
# ..              ...             ...                      ...
# 151           0.359        1.205915                    0.614
# 152           0.476        0.885000                    0.499
# 153           0.350        0.517000                    0.361
# 154           0.026        0.000000                    0.105
# 155           0.306        0.575000                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                           0.681     0.20200                      0.393  2018
# 1                           0.686     0.28600                      0.340  2018
# 2                           0.683     0.28400                      0.408  2018
# 3                           0.677     0.18136                      0.138  2018
# 4                           0.660     0.25600                      0.357  2018
# ..                            ...         ...                        ...   ...
# 151                         0.555     0.21700                      0.411  2019
# 152                         0.417     0.27600                      0.147  2019
# 153                         0.000     0.15800                      0.025  2019
# 154                         0.225     0.23500                      0.035  2019
# 155                         0.010     0.20200                      0.091  2019
#
# [312 rows x 11 columns]

# %%
wh.fillna(wh2019.mean())
# Out:
# C:\Users\artic\AppData\Local\Temp/ipykernel_182884/1370626197.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wh.fillna(wh2019.mean())
#      Unnamed: 0  Overall rank         Country or region  Score  \
# 0           0.0             1                   Finland  7.632
# 1           1.0             2                    Norway  7.594
# 2           2.0             3                   Denmark  7.555
# 3           3.0             4                   Iceland  7.495
# 4           4.0             5               Switzerland  7.487
# ..          ...           ...                       ...    ...
# 151         NaN           152                    Rwanda  3.334
# 152         NaN           153                  Tanzania  3.231
# 153         NaN           154               Afghanistan  3.203
# 154         NaN           155  Central African Republic  3.083
# 155         NaN           156               South Sudan  2.853
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.305        1.592000                    0.874
# 1             1.456        1.582000                    0.861
# 2             1.351        1.590000                    0.868
# 3             1.343        1.207702                    0.914
# 4             1.420        1.549000                    0.927
# ..              ...             ...                      ...
# 151           0.359        1.207702                    0.614
# 152           0.476        0.885000                    0.499
# 153           0.350        0.517000                    0.361
# 154           0.026        0.000000                    0.105
# 155           0.306        0.575000                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                           0.681    0.202000                      0.393  2018
# 1                           0.686    0.286000                      0.340  2018
# 2                           0.683    0.284000                      0.408  2018
# 3                           0.677    0.184075                      0.138  2018
# 4                           0.660    0.256000                      0.357  2018
# ..                            ...         ...                        ...   ...
# 151                         0.555    0.217000                      0.411  2019
# 152                         0.417    0.276000                      0.147  2019
# 153                         0.000    0.158000                      0.025  2019
# 154                         0.225    0.235000                      0.035  2019
# 155                         0.010    0.202000                      0.091  2019
#
# [312 rows x 11 columns]

# %% [markdown]
# # 4. Partiendo de Wh limpio, para cada metrica por pais, muestra la diferencia del ultimo valor encontrado contra el primero.

# %% [markdown]
# Ejemplo:

# %%
wh.loc[ wh['Country or region'] == 'Switzerland' , : ]
# Out:
#    Unnamed: 0  Overall rank Country or region  Score  GDP per capita  \
# 4         4.0             5       Switzerland  7.487           1.420
# 5         NaN             6       Switzerland  7.480           1.452
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 4           1.549                    0.927                         0.660
# 5           1.526                    1.052                         0.572
#
#    Generosity  Perceptions of corruption  year
# 4       0.256                      0.357  2018
# 5       0.263                      0.343  2019

# %%
wh2018
# Out:
#      Unnamed: 0  Overall rank         Country or region  Score  \
# 0             0             1                   Finland  7.632
# 1             1             2                    Norway  7.594
# 2             2             3                   Denmark  7.555
# 3             3             4                   Iceland  7.495
# 4             4             5               Switzerland  7.487
# ..          ...           ...                       ...    ...
# 151         151           152                     Yemen  3.355
# 152         152           153                  Tanzania  3.303
# 153         153           154               South Sudan  3.254
# 154         154           155  Central African Republic  3.083
# 155         155           156                   Burundi  2.905
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.305           1.592                    0.874
# 1             1.456           1.582                    0.861
# 2             1.351           1.590                    0.868
# 3             1.343             NaN                    0.914
# 4             1.420           1.549                    0.927
# ..              ...             ...                      ...
# 151           0.442           1.073                    0.343
# 152           0.455             NaN                    0.381
# 153           0.337             NaN                    0.177
# 154           0.024           0.000                    0.010
# 155           0.091           0.627                    0.145
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                           0.681       0.202                      0.393  2018
# 1                           0.686       0.286                      0.340  2018
# 2                           0.683       0.284                      0.408  2018
# 3                           0.677         NaN                      0.138  2018
# 4                           0.660       0.256                      0.357  2018
# ..                            ...         ...                        ...   ...
# 151                         0.244       0.083                        NaN  2018
# 152                         0.481       0.270                      0.097  2018
# 153                         0.112       0.224                      0.106  2018
# 154                         0.305       0.218                      0.038  2018
# 155                         0.065       0.149                      0.076  2018
#
# [156 rows x 11 columns]

# %%
wh2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151             NaN                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption  year
# 0         0.153                      0.393  2019
# 1         0.252                      0.410  2019
# 2         0.271                      0.341  2019
# 3         0.354                      0.118  2019
# 4         0.322                      0.298  2019
# ..          ...                        ...   ...
# 151       0.217                      0.411  2019
# 152       0.276                      0.147  2019
# 153       0.158                      0.025  2019
# 154       0.235                      0.035  2019
# 155       0.202                      0.091  2019
#
# [156 rows x 10 columns]

# %%
wh = wh2018.loc[:, ['Score','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']] - wh2019.loc[:,['Score','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']]

# %%
wh
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 0   -0.137          -0.035           0.005                   -0.112
# 1   -0.006           0.073           0.009                   -0.135
# 2    0.001          -0.137           0.008                   -0.160
# 3    0.001          -0.037             NaN                   -0.112
# 4   -0.001           0.024           0.027                   -0.072
# ..     ...             ...             ...                      ...
# 151  0.021           0.083             NaN                   -0.271
# 152  0.072          -0.021             NaN                   -0.118
# 153  0.051          -0.013             NaN                   -0.184
# 154  0.000          -0.002           0.000                   -0.095
# 155  0.052          -0.215           0.052                   -0.150
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 0                           0.085       0.049                      0.000
# 1                           0.094       0.034                     -0.070
# 2                           0.080       0.013                      0.067
# 3                           0.086         NaN                      0.020
# 4                           0.103      -0.066                      0.059
# ..                            ...         ...                        ...
# 151                        -0.311      -0.134                        NaN
# 152                         0.064      -0.006                     -0.050
# 153                         0.112       0.066                      0.081
# 154                         0.080      -0.017                      0.003
# 155                         0.055      -0.053                     -0.015
#
# [156 rows x 7 columns]
